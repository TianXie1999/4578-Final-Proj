# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('covid19data.csv')
df
# Out:
# G:\Users\72313\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (104,130,131,132,135) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          state  fips        date   cases  deaths  metro_area iso_3166_2_code  \
# 0      Alabama     1  2020-01-22     0.0     0.0         NaN             NaN
# 1      Alabama     1  2020-01-23     0.0     0.0         NaN             NaN
# 2      Alabama     1  2020-01-24     0.0     0.0         NaN             NaN
# 3      Alabama     1  2020-01-25     0.0     0.0         NaN             NaN
# 4      Alabama     1  2020-01-26     0.0     0.0         NaN             NaN
# ...        ...   ...         ...     ...     ...         ...             ...
# 10502  Wyoming    56  2020-08-10  3042.0    28.0         NaN           US-WY
# 10503  Wyoming    56  2020-08-11  3073.0    29.0         NaN           US-WY
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10507 entries, 0 to 10506
# Data columns (total 151 columns):
#  #   Column                                                                                                                     Dtype
# ---  ------                                                                                                                     -----
#  0   state                                                                                                                      object
#  1   fips                                                                                                                       int64
#  2   date                                                                                                                       object
#  3   cases                                                                                                                      float64
# ...

# %%
df['positiveIncrease'].isna().sum()
# Out:
# 2178

# %%
df[df['state'] == 'Michigan']
# Out:
#          state  fips        date    cases  deaths  metro_area iso_3166_2_code  \
# 4532  Michigan    26  2020-01-22      0.0     0.0         NaN             NaN
# 4533  Michigan    26  2020-01-23      0.0     0.0         NaN             NaN
# 4534  Michigan    26  2020-01-24      0.0     0.0         NaN             NaN
# 4535  Michigan    26  2020-01-25      0.0     0.0         NaN             NaN
# 4536  Michigan    26  2020-01-26      0.0     0.0         NaN             NaN
# ...        ...   ...         ...      ...     ...         ...             ...
# 4733  Michigan    26  2020-08-10  97306.0  6526.0         NaN           US-MI
# 4734  Michigan    26  2020-08-11  98213.0  6533.0         NaN           US-MI
# 4735  Michigan    26  2020-08-12  98689.0  6539.0         NaN             NaN
# 4736  Michigan    26  2020-08-13  99856.0  6555.0         NaN             NaN
# 4737  Michigan    26  2020-08-14      NaN     NaN         NaN             NaN
#
# ...

# %% [markdown]
# 2020.1.22 - 8.14算出来各个州感染的population percentage,然后找confounder，最后算mask percentage的影响
