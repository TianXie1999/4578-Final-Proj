# %%
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

import scipy
import warnings
warnings.filterwarnings('ignore')

def mean_str(col):
    if is_numeric_dtype(col):
        return col.mean()
    else:
        return col.unique() if col.nunique() == 1 else np.NaN

# %% [markdown]
# ## Import Data and Data Cleaning

# %%
df = pd.read_csv('covid19data.csv')
df[df['state'] == 'Alabama']
# Out:
#        state  fips        date     cases  deaths  metro_area iso_3166_2_code  \
# 0    Alabama     1  2020-01-22       0.0     0.0         NaN             NaN
# 1    Alabama     1  2020-01-23       0.0     0.0         NaN             NaN
# 2    Alabama     1  2020-01-24       0.0     0.0         NaN             NaN
# 3    Alabama     1  2020-01-25       0.0     0.0         NaN             NaN
# 4    Alabama     1  2020-01-26       0.0     0.0         NaN             NaN
# ..       ...   ...         ...       ...     ...         ...             ...
# 201  Alabama     1  2020-08-10  103020.0  1797.0         NaN           US-AL
# 202  Alabama     1  2020-08-11  103851.0  1847.0         NaN           US-AL
# 203  Alabama     1  2020-08-12  104786.0  1882.0         NaN             NaN
# 204  Alabama     1  2020-08-13  105557.0  1890.0         NaN             NaN
# 205  Alabama     1  2020-08-14       NaN     NaN         NaN             NaN
#
#      census_fips_code  retail_and_recreation_percent_change_from_baseline  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ..                ...                                                ...
# 201               NaN                                               -7.0
# 202               NaN                                               -8.0
# 203               NaN                                                NaN
# 204               NaN                                                NaN
# 205               NaN                                                NaN
#
#      grocery_and_pharmacy_percent_change_from_baseline  ...  \
# 0                                                  NaN  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 201                                               -1.0  ...
# 202                                                0.0  ...
# 203                                                NaN  ...
# 204                                                NaN  ...
# 205                                                NaN  ...
#
#      Number.Homeless..2019.  Percent.Unemployed..2018.  \
# 0                      3261                        5.6
# 1                      3261                        5.6
# 2                      3261                        5.6
# 3                      3261                        5.6
# 4                      3261                        5.6
# ..                      ...                        ...
# 201                    3261                        5.6
# 202                    3261                        5.6
# 203                    3261                        5.6
# 204                    3261                        5.6
# 205                    3261                        5.6
#
#      Percent.living.under.the.federal.poverty.line..2018.  \
# 0                                                 16.8
# 1                                                 16.8
# 2                                                 16.8
# 3                                                 16.8
# 4                                                 16.8
# ..                                                 ...
# 201                                               16.8
# 202                                               16.8
# 203                                               16.8
# 204                                               16.8
# 205                                               16.8
#
#      Percent.at.risk.for.serious.illness.due.to.COVID  All.cause.deaths.2018  \
# 0                                                43.1                  54352
# 1                                                43.1                  54352
# 2                                                43.1                  54352
# 3                                                43.1                  54352
# 4                                                43.1                  54352
# ..                                                ...                    ...
# 201                                              43.1                  54352
# 202                                              43.1                  54352
# 203                                              43.1                  54352
# 204                                              43.1                  54352
# 205                                              43.1                  54352
#
#      Mental.health.professionals.per.100.000.population.in.2019       party  \
# 0                                                100.7           republican
# 1                                                100.7           republican
# 2                                                100.7           republican
# 3                                                100.7           republican
# 4                                                100.7           republican
# ..                                                 ...                  ...
# 201                                              100.7           republican
# 202                                              100.7           republican
# 203                                              100.7           republican
# 204                                              100.7           republican
# 205                                              100.7           republican
#
#      voteshare  z.mask  mask_percent
# 0     0.620831   -3.62            38
# 1     0.620831   -3.62            38
# 2     0.620831   -3.62            38
# 3     0.620831   -3.62            38
# 4     0.620831   -3.62            38
# ..         ...     ...           ...
# 201   0.620831   -3.62            38
# 202   0.620831   -3.62            38
# 203   0.620831   -3.62            38
# 204   0.620831   -3.62            38
# 205   0.620831   -3.62            38
#
# [206 rows x 151 columns]

# %%
df = pd.read_csv('covid19data.csv')
new_df = df.groupby('state').agg(mean_str).dropna('columns').reset_index()
# new_df = new_df.drop(columns=['iso_3166_2_code'])

# %%
new_df.head()
# Out:
#         state  fips          cases       deaths iso_3166_2_code  \
# 0     Alabama   1.0   21931.034146   503.595122    [nan, US-AL]
# 1      Alaska   2.0     699.804878     8.721951    [nan, US-AK]
# 2     Arizona   4.0   40718.185366   949.268293    [nan, US-AZ]
# 3    Arkansas   5.0   10736.765854   135.009756    [nan, US-AR]
# 4  California   6.0  130271.287805  3162.078049    [nan, US-CA]
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                         -11.726257
# 1                                          -2.932961
# 2                                         -21.212291
# 3                                          -7.536313
# 4                                         -31.519553
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                           2.491620
# 1                                           7.223464
# 2                                          -6.530726
# 3                                           5.530726
# 4                                          -7.145251
#
#    parks_percent_change_from_baseline  \
# 0                           31.748603
# 1                           97.752809
# 2                          -10.268156
# 3                           67.681564
# 4                           -5.312849
#
#    transit_stations_percent_change_from_baseline  \
# 0                                      -5.357542
# 1                                     -14.882682
# 2                                     -26.022346
# 3                                      -6.301676
# 4                                     -37.212291
#
#    workplaces_percent_change_from_baseline  ...  Number.Homeless..2019.  \
# 0                               -23.810056  ...                  3261.0
# 1                               -23.011173  ...                  1907.0
# 2                               -30.413408  ...                 10007.0
# 3                               -22.569832  ...                  2717.0
# 4                               -33.346369  ...                151278.0
#
#    Percent.Unemployed..2018.  \
# 0                        5.6
# 1                        6.8
# 2                        5.4
# 3                        4.5
# 4                        5.5
#
#    Percent.living.under.the.federal.poverty.line..2018.  \
# 0                                               16.8
# 1                                               10.9
# 2                                               14.0
# 3                                               17.2
# 4                                               12.8
#
#    Percent.at.risk.for.serious.illness.due.to.COVID  All.cause.deaths.2018  \
# 0                                              43.1                54352.0
# 1                                              32.8                 4453.0
# 2                                              39.1                59282.0
# 3                                              43.5                32336.0
# 4                                              33.3               268818.0
#
#    Mental.health.professionals.per.100.000.population.in.2019       party  \
# 0                                              100.7           republican
# 1                                              429.9           republican
# 2                                              132.9           republican
# 3                                              231.6           republican
# 4                                              356.2             democrat
#
#    voteshare  z.mask  mask_percent
# 0   0.620831   -3.62          38.0
# 1   0.512815   -0.25          42.0
# 2   0.486716   -7.43          36.0
# 3   0.605741   -2.08          39.0
# 4   0.316171   18.16          52.0
#
# [5 rows x 90 columns]

# %%
from sklearn.preprocessing import LabelEncoder
# Encode the party
le = LabelEncoder()
le.fit(new_df['party'])
new_df['party'] = le.transform(new_df['party'])

# %%
le.classes_
# Out:
# array(['democrat', 'republican'], dtype=object)

# %%
indexes = ['State.of.emergency', 
           'Date.closed.K.12.schools', 
           'Closed.Bars', 
           'Reopened.hair.salons.barber.shops', 
           'Reopen.non.essential.construction', 
           'Reopen.Religious.gatherings', 
           'Reopen.non.essential.retail', 
           'Reopen.bars', 
           'Reopen.Childcare',
           'Lift.Eviction.Moratorium',
           'SNAP.Waiver.Emergency.Allotments.to.Current.SNAP.Households',
           'SNAP.Waiver.Pandemic.EBT',
           'SNAP.Waiver.Temporary.Suspension.of.Claims.Collection', 
           'Modify.Medicaid.requirements.with.1135.waivers..date.of.CMS.approval.', 
           'Reopened.ACA.enrollment.using.a.special.enrollment.period', 
           'Allow.audio.only.telehealth', 
           'Allow.expand.Medicaid.telehealth.coverage', 
           'Suspended.elective.medical.dental.procedures', 
           'Use.of.telemedicine.for.schedule.II.V.prescriptions', 
           'Exceptions.to.emergency.oral.prescriptions']

for i in indexes:
    for j in range(len(new_df[i])):
        if new_df[i].loc[j] != 0:
            new_df[i].loc[j] = 1
            
# cases is found by running Cases.ipynb
final_df = pd.read_csv('data_for_causal_inference.csv')
new_df['cases'] = final_df['cases']
corr = new_df.corr()
new_df.to_csv('mask_data.csv')
new_df.head()
# Out:
#         state  fips       cases       deaths iso_3166_2_code  \
# 0     Alabama   1.0  116.673258   503.595122    [nan, US-AL]
# 1      Alaska   2.0   99.200836     8.721951    [nan, US-AK]
# 2     Arizona   4.0  129.978430   949.268293    [nan, US-AZ]
# 3    Arkansas   5.0  128.983199   135.009756    [nan, US-AR]
# 4  California   6.0  101.290718  3162.078049    [nan, US-CA]
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                         -11.726257
# 1                                          -2.932961
# 2                                         -21.212291
# 3                                          -7.536313
# 4                                         -31.519553
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                           2.491620
# 1                                           7.223464
# 2                                          -6.530726
# 3                                           5.530726
# 4                                          -7.145251
#
#    parks_percent_change_from_baseline  \
# 0                           31.748603
# 1                           97.752809
# 2                          -10.268156
# 3                           67.681564
# 4                           -5.312849
#
#    transit_stations_percent_change_from_baseline  \
# 0                                      -5.357542
# 1                                     -14.882682
# 2                                     -26.022346
# 3                                      -6.301676
# 4                                     -37.212291
#
#    workplaces_percent_change_from_baseline  ...  Number.Homeless..2019.  \
# 0                               -23.810056  ...                  3261.0
# 1                               -23.011173  ...                  1907.0
# 2                               -30.413408  ...                 10007.0
# 3                               -22.569832  ...                  2717.0
# 4                               -33.346369  ...                151278.0
#
#    Percent.Unemployed..2018.  \
# 0                        5.6
# 1                        6.8
# 2                        5.4
# 3                        4.5
# 4                        5.5
#
#    Percent.living.under.the.federal.poverty.line..2018.  \
# 0                                               16.8
# 1                                               10.9
# 2                                               14.0
# 3                                               17.2
# 4                                               12.8
#
#    Percent.at.risk.for.serious.illness.due.to.COVID  All.cause.deaths.2018  \
# 0                                              43.1                54352.0
# 1                                              32.8                 4453.0
# 2                                              39.1                59282.0
# 3                                              43.5                32336.0
# 4                                              33.3               268818.0
#
#    Mental.health.professionals.per.100.000.population.in.2019  party  \
# 0                                              100.7               1
# 1                                              429.9               1
# 2                                              132.9               1
# 3                                              231.6               1
# 4                                              356.2               0
#
#    voteshare  z.mask  mask_percent
# 0   0.620831     0.0          38.0
# 1   0.512815     0.0          42.0
# 2   0.486716     0.0          36.0
# 3   0.605741     0.0          39.0
# 4   0.316171     1.0          52.0
#
# [5 rows x 90 columns]

# %% [markdown]
# **Democrate: 1, Republican: 0**
#
# **Have legal enforcement: 0, not have: 1**
#
# So we change it to reversed edtion

# %%
new_df['legal_enforcement'] = 1 - new_df['No.legal.enforcement.of.face.mask.mandate']

# %%
import seaborn as sns
examine = new_df[['party','legal_enforcement']]
examine.groupby('party').sum()
# Out:
#        legal_enforcement
# party
# 0                   10.0
# 1                   20.0

# %%
examine.corr()
# Out:
#                       party  legal_enforcement
# party              1.000000           0.375046
# legal_enforcement  0.375046           1.000000

# %%
loc1 = new_df['z.mask'] > 0
loc2 = new_df['z.mask'] <= 0
new_df['z.mask'][loc1] = 1
new_df['z.mask'][loc2] = 0

# %% [markdown]
# ## Data Analysis and Confounders Extraction

# %%
places = ['Initially.reopen.restaurants.for.outdoor.dining.only', 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'parks_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']
unsure = ['percentchangehours', 'percentchangebusinesses', 'Waive.work.search.requirement.for.unemployment.insurance', 'Expand.eligibility.of.unemployment.insurance.to.those.who.have.lost.childcare.school.closures', 'Paid.sick.leave', 'Mental.health.professionals.per.100.000.population.in.2019', 'voteshare', 'Expand.eligibility.to.high.risk.individuals.in.preventative.quarantine']
policy = ['Religious.Gatherings.Exempt.Without.Clear.Social.Distance.Mandate.', 'Face.mask.mandate.enforced.by.fines', 'Face.mask.mandate.enforced.by.criminal.charge.citation', 'z.mask', 'Expand.eligibility.of.unemployment.insurance.to.anyonewho.is.quarantined.and.or.taking.care.of.someone.who.is.quarantined', 'Weekly.unemployment.insurance.maximum.amount..dollars.', 'Medicaid.Expansion', 'Percent.at.risk.for.serious.illness.due.to.COVID']
population = ['Population.2018', 'Number.Homeless..2019.', 'Percent.Unemployed..2018.', 'Population.density.per.square.miles']

All_index = places+unsure+policy+population+['cases', 'mask_percent']

# %%
corr = new_df.corr()['cases']
corr.sort_values(ascending = False)
cases_corr_strong = corr[abs(corr) >= 0.1 ]
cases_corr_strong
# Out:
# cases                                                                                                                        1.000000
# deaths                                                                                                                      -0.104758
# retail_and_recreation_percent_change_from_baseline                                                                           0.311293
# grocery_and_pharmacy_percent_change_from_baseline                                                                            0.436364
# parks_percent_change_from_baseline                                                                                           0.375084
# transit_stations_percent_change_from_baseline                                                                                0.339881
# workplaces_percent_change_from_baseline                                                                                      0.325712
# residential_percent_change_from_baseline                                                                                    -0.244108
# percentchangehours                                                                                                           0.534896
# percentchangebusinesses                                                                                                      0.405366
# cases.nyt                                                                                                                   -0.100778
# deaths.nyt                                                                                                                  -0.105850
# deaths.ctp                                                                                                                  -0.105303
# deathIncrease                                                                                                               -0.103809
# Initially.reopen.restaurants.for.outdoor.dining.only                                                                        -0.245773
# Face.mask.mandate.enforced.by.fines                                                                                         -0.185705
# Face.mask.mandate.enforced.by.criminal.charge.citation                                                                      -0.124271
# No.legal.enforcement.of.face.mask.mandate                                                                                   -0.133834
# Expand.eligibility.of.unemployment.insurance.to.anyonewho.is.quarantined.and.or.taking.care.of.someone.who.is.quarantined    0.149077
# Expand.eligibility.of.unemployment.insurance.to.those.who.have.lost.childcare.school.closures                                0.146377
# Weekly.unemployment.insurance.maximum.amount..dollars.                                                                      -0.113710
# Weekly.unemployment.insurance.maximum.amount.with.extra.stimulus..through.July.21..2020...dollars.                          -0.113710
# Paid.sick.leave                                                                                                             -0.143759
# Medicaid.Expansion                                                                                                          -0.256817
# Population.density.per.square.miles                                                                                         -0.107582
# Percent.Unemployed..2018.                                                                                                   -0.223320
# Percent.at.risk.for.serious.illness.due.to.COVID                                                                            -0.111207
# All.cause.deaths.2018                                                                                                       -0.104480
# Mental.health.professionals.per.100.000.population.in.2019                                                                  -0.211852
# party                                                                                                                        0.189482
# voteshare                                                                                                                    0.304162
# z.mask                                                                                                                      -0.142021
# mask_percent                                                                                                                -0.262810
# legal_enforcement                                                                                                            0.133834
# Name: cases, dtype: float64

# %%
corr = new_df.corr()['mask_percent']
corr.sort_values(ascending = False)
mask_corr_strong = corr[abs(corr) >= 0.05]
mask_corr_strong
# Out:
# fips                                                                                                                        -0.188856
# cases                                                                                                                       -0.262810
# deaths                                                                                                                       0.434221
# retail_and_recreation_percent_change_from_baseline                                                                          -0.710324
# grocery_and_pharmacy_percent_change_from_baseline                                                                           -0.772391
# parks_percent_change_from_baseline                                                                                          -0.503485
# transit_stations_percent_change_from_baseline                                                                               -0.765853
# workplaces_percent_change_from_baseline                                                                                     -0.718987
# residential_percent_change_from_baseline                                                                                     0.790393
# percentchangehours                                                                                                          -0.705504
# percentchangebusinesses                                                                                                     -0.670400
# cases.nyt                                                                                                                    0.424147
# deaths.nyt                                                                                                                   0.428846
# positive                                                                                                                     0.425595
# negative                                                                                                                     0.370888
# hospitalizedCurrently                                                                                                        0.365072
# deaths.ctp                                                                                                                   0.464713
# positiveIncrease                                                                                                             0.313261
# negativeIncrease                                                                                                             0.363803
# total                                                                                                                        0.378401
# totalTestResults                                                                                                             0.381197
# totalTestResultsIncrease                                                                                                     0.365672
# posNeg                                                                                                                       0.378430
# deathIncrease                                                                                                                0.480416
# hospitalizedIncrease                                                                                                         0.283149
# State.FIPS.Code                                                                                                             -0.188856
# Initially.reopen.restaurants.for.outdoor.dining.only                                                                         0.371564
# Face.mask.mandate.enforced.by.fines                                                                                          0.357563
# Face.mask.mandate.enforced.by.criminal.charge.citation                                                                       0.222777
# No.legal.enforcement.of.face.mask.mandate                                                                                    0.085888
# Prior.to.pandemic..no.state.unemployment.waiting.period..or.date.waiting.period.waived.not.found                             0.152462
# Waive.work.search.requirement.for.unemployment.insurance                                                                    -0.110041
# Expand.eligibility.of.unemployment.insurance.to.anyonewho.is.quarantined.and.or.taking.care.of.someone.who.is.quarantined   -0.207902
# Expand.eligibility.to.high.risk.individuals.in.preventative.quarantine                                                      -0.118335
# Expand.eligibility.of.unemployment.insurance.to.those.who.have.lost.childcare.school.closures                                0.183142
# Weekly.unemployment.insurance.maximum.amount..dollars.                                                                       0.217674
# Weekly.unemployment.insurance.maximum.amount.with.extra.stimulus..through.July.21..2020...dollars.                           0.217674
# Unemployment.insurance.maximum.duration..weeks.                                                                              0.072640
# Unemployment.insurance.maximum.duration.with.Pandemic.Emergency.Unemployment.Compensation.CARES.extension..weeks.            0.072640
# X2020.Q1.SNAP.ABAWD.Time.Limit.Waiver                                                                                        0.220154
# State.previously.allowed.audio.only.telehealth                                                                               0.077126
# State.had.CHIP.premium.non.payment.lock.out.period.as.of.January.2019                                                       -0.061173
# Supend.CHIP.premium.non.payment.lock.outs                                                                                   -0.104248
# Made.Effort.to.Limit.Abortion.Access                                                                                        -0.231924
# Paid.sick.leave                                                                                                              0.486985
# Medicaid.Expansion                                                                                                           0.209172
# Population.density.per.square.miles                                                                                          0.362031
# Population.2018                                                                                                              0.296337
# Square.Miles                                                                                                                -0.111622
# Number.Homeless..2019.                                                                                                       0.361657
# Percent.Unemployed..2018.                                                                                                    0.440807
# Percent.living.under.the.federal.poverty.line..2018.                                                                        -0.124920
# Percent.at.risk.for.serious.illness.due.to.COVID                                                                            -0.178818
# All.cause.deaths.2018                                                                                                        0.266102
# Mental.health.professionals.per.100.000.population.in.2019                                                                   0.293054
# party                                                                                                                       -0.318848
# voteshare                                                                                                                   -0.656857
# z.mask                                                                                                                       0.805068
# mask_percent                                                                                                                 1.000000
# legal_enforcement                                                                                                           -0.085888
# Name: mask_percent, dtype: float64

# %% [markdown]
# ### Conclusion
# 1. Factors such as grocery, retail, workplace, and recreation may actually be influenced by our y (covid cases), so not meaningful to be included in the DAG though they have very high correlatioin
#
# 2. Some factors like z-score of masking, positive cases, death cases are strongly correlated with our variables of interest, but having no value to research
#
# 3. Good confounders are **residential_percent_change_from_baseline**, **Number Homeless**,**Percent.Unemployed..2018.**, **Population.density.per.square.miles**. These are likely to both influence wearing masks and covid cases
#
# 4. Good Instrument Variable would be: **party**. This would be great because it has strong correlation to mask policy, but is not likely to have backdoor path to covid cases
#
# 5. Other variables may still have strong correlation to both, but they also have strong collinearity with the ones we already add to DAG. Thus, we just discard them
#
# Here is the DAG:
#
# M is z.mask on mask (treatment), Y is result (Cases in 1000), A is known confounders, U is possible unobserved confounders, Z is party, which is a possible instrument variable

# %% [markdown]
# ![DAG](DAG.png)

# %%
extraction = ['residential_percent_change_from_baseline', 'Number.Homeless..2019.', 'Percent.Unemployed..2018.','Population.density.per.square.miles','z.mask','legal_enforcement', 'party','cases', 'state']
final_df = new_df[extraction]

# %%
final_df.head()
# Out:
#    residential_percent_change_from_baseline  Number.Homeless..2019.  \
# 0                                  7.782123                  3261.0
# 1                                  6.653631                  1907.0
# 2                                 10.050279                 10007.0
# 3                                  6.391061                  2717.0
# 4                                 12.960894                151278.0
#
#    Percent.Unemployed..2018.  Population.density.per.square.miles  z.mask  \
# 0                        5.6                                93.24     0.0
# 1                        6.8                                 1.11     0.0
# 2                        5.4                                62.91     0.0
# 3                        4.5                                56.67     0.0
# 4                        5.5                               241.65     1.0
#
#    legal_enforcement  party       cases       state
# 0                0.0      1  116.673258     Alabama
# 1                1.0      1   99.200836      Alaska
# 2                1.0      1  129.978430     Arizona
# 3                1.0      1  128.983199    Arkansas
# 4                0.0      0  101.290718  California

# %%
final_df.to_csv('data_for_causal_inference.csv')

# %% [markdown]
# ## Treatment Effect Computation
# ### IP Weighting Method

# %%
# simplyfy variable name
final_df = final_df.rename(columns={"residential_percent_change_from_baseline": "A1", "Number.Homeless..2019.": "A2",
                        "Percent.Unemployed..2018.": "A3", "Population.density.per.square.miles": "A4",
                        "z.mask": "M","party": "Z", "cases": "Y"})
# ip weighting
weight_mod = smf.logit('M ~ A1 + A2 + A3 + A4', data=final_df).fit()
final_df['prop'] = weight_mod.predict(final_df)
final_df['weight'] = 1 / final_df['prop']
loc = final_df['M'] == 0
final_df['weight'][loc] = 1 / (1 - final_df['prop'])
final_df
# Out:
# Optimization terminated successfully.
#          Current function value: 0.296909
#          Iterations 9
#            A1        A2   A3        A4    M  legal_enforcement  Z           Y  \
# 0    7.782123    3261.0  5.6     93.24  0.0                0.0  1  116.673258
# 1    6.653631    1907.0  6.8      1.11  0.0                1.0  1   99.200836
# 2   10.050279   10007.0  5.4     62.91  0.0                1.0  1  129.978430
# 3    6.391061    2717.0  4.5     56.67  0.0                1.0  1  128.983199
# 4   12.960894  151278.0  5.5    241.65  1.0                0.0  0  101.290718
# 5   10.184358    9619.0  3.9     54.72  1.0                1.0  0  100.166548
# 6   11.150838    3033.0  5.5    644.54  1.0                0.0  0   98.493765
# 7   10.301676     921.0  5.7    388.58  0.0                1.0  0  160.546447
# 8   16.664804    6521.0  7.5  11496.81  1.0                1.0  0   51.119857
# 9   10.636872   28328.0  5.2    323.90  1.0                1.0  1  122.907374
# 10   9.770950   10443.0  4.8    177.02  1.0                1.0  1  110.821247
# 11  12.972067    6412.0  3.8    129.94  1.0                1.0  0   28.235291
# 12   5.675978    2315.0  4.0     20.99  0.0                1.0  1  109.325944
# 13  10.709497   10199.0  5.5    220.00  1.0                0.0  0  111.181864
# 14   8.044693    5471.0  4.4    183.74  0.0                1.0  1  113.942939
# 15   7.335196    2315.0  3.6     56.09  0.0                1.0  1  116.355648
# 16   7.519553    2381.0  3.8     35.39  0.0                0.0  0  113.710226
# 17   7.994413    4079.0  5.2    110.58  0.0                0.0  1  107.325034
# 18   8.893855    2941.0  6.4     88.97  0.0                0.0  0  117.885712
# 19   7.804469    2106.0  3.5     37.83  0.0                0.0  0   51.865918
# 20  13.234637    6561.0  4.9    487.08  1.0                1.0  1   75.939451
# 21  13.296089   18471.0  4.8    653.98  1.0                1.0  1  102.587555
# 22  10.446927    8575.0  5.3    103.36  1.0                0.0  0  100.889214
# 23  10.458101    7977.0  3.4     64.54  0.0                1.0  0  107.441627
# 24   7.022346    1184.0  7.1     61.66  1.0                0.0  1  117.684284
# 25   7.374302    6179.0  4.2     87.89  0.0                1.0  1  110.925695
# 26   5.072626    1357.0  3.5      7.22  0.0                1.0  0  107.488759
# 27   8.156425    2365.0  3.5     24.94  0.0                1.0  1  116.762444
# 28  11.016760    7169.0  5.6     27.44  1.0                1.0  0  115.340265
# 29  10.100559    1396.0  3.6    145.09  1.0                1.0  1   73.228948
# 30  14.229050    8862.0  4.9   1021.27  1.0                0.0  0  111.990706
# 31   9.513966    3241.0  6.1     17.23  0.0                0.0  0   99.707110
# 32  13.513966   92091.0  5.0    358.21  1.0                1.0  0   58.117100
# 33   8.754190    9314.0  5.0    192.94  0.0                0.0  0  100.643352
# 34   6.854749     557.0  2.8     10.75  0.0                1.0  1  143.338288
# 35   8.681564   10345.0  4.9    260.77  0.0                0.0  1   95.778548
# 36   6.994413    3944.0  4.4     56.41  0.0                1.0  1  122.689490
# 37   8.843575   15876.0  5.0     42.60  0.0                0.0  0   52.184008
# 38  10.541899   13199.0  4.9    278.09  1.0                0.0  0   94.752167
# 39  10.592179    1055.0  5.5    684.35  1.0                0.0  0  133.775113
# 40   7.765363    4172.0  5.3    158.78  0.0                1.0  1    0.000801
# 41   6.832402     995.0  3.0     11.44  0.0                1.0  1  702.845600
# 42   7.435754    7467.0  5.5    160.64  0.0                1.0  1  129.955838
# 43  11.039106   25848.0  4.9    106.86  1.0                1.0  1  107.327082
# 44   8.670391    2798.0  3.2     37.23  0.0                0.0  1  135.361412
# 45  10.055866    1089.0  3.8     65.13  0.0                0.0  1   36.292699
# 46  11.089385    5783.0  4.2    199.13  0.0                1.0  0   80.879413
# 47  10.865922   21577.0  4.3    105.69  0.0                0.0  0   61.561415
# 48   6.810056    1397.0  5.8     74.53  0.0                0.0  0   93.358146
# 49   9.072626    4538.0  3.2     88.76  0.0                1.0  0  116.834229
# 50   5.391061     548.0  3.9      5.91  0.0                1.0  1  113.289220
#
#                    state      prop     weight
# 0                Alabama  0.076379   1.082696
# 1                 Alaska  0.046280   1.048526
# 2                Arizona  0.523332   2.097897
# 3               Arkansas  0.006008   1.006045
# 4             California  0.999865   1.000135
# 5               Colorado  0.258999   3.861014
# 6            Connecticut  0.925264   1.080772
# 7               Delaware  0.741989   3.875796
# 8   District of Columbia  1.000000   1.000000
# 9                Florida  0.862918   1.158859
# 10               Georgia  0.388338   2.575077
# 11                Hawaii  0.890923   1.122431
# 12                 Idaho  0.001592   1.001595
# 13              Illinois  0.785055   1.273796
# 14               Indiana  0.051182   1.053943
# 15                  Iowa  0.008106   1.008172
# 16                Kansas  0.011281   1.011410
# 17              Kentucky  0.074518   1.080518
# 18             Louisiana  0.360766   1.564373
# 19                 Maine  0.012060   1.012207
# 20              Maryland  0.984476   1.015769
# 21         Massachusetts  0.992892   1.007159
# 22              Michigan  0.623158   1.604729
# 23             Minnesota  0.232095   1.302244
# 24           Mississippi  0.096260  10.388535
# 25              Missouri  0.017178   1.017478
# 26               Montana  0.000492   1.000493
# 27              Nebraska  0.017552   1.017865
# 28                Nevada  0.765275   1.306719
# 29         New Hampshire  0.184797   5.411337
# 30            New Jersey  0.998624   1.001378
# 31            New Mexico  0.432457   1.761981
# 32              New York  0.999317   1.000684
# 33        North Carolina  0.190305   1.235033
# 34          North Dakota  0.002035   1.002039
# 35                  Ohio  0.194136   1.240905
# 36              Oklahoma  0.011404   1.011535
# 37                Oregon  0.188813   1.232762
# 38          Pennsylvania  0.697969   1.432728
# 39          Rhode Island  0.869941   1.149503
# 40        South Carolina  0.070280   1.075593
# 41          South Dakota  0.002388   1.002394
# 42             Tennessee  0.064864   1.069363
# 43                 Texas  0.811622   1.232100
# 44                  Utah  0.025366   1.026026
# 45               Vermont  0.173597   1.210064
# 46              Virginia  0.605365   2.533985
# 47            Washington  0.646399   2.828046
# 48         West Virginia  0.028177   1.028994
# 49             Wisconsin  0.046948   1.049261
# 50               Wyoming  0.000960   1.000961

# %%
# ip weighting with a weighted logistic regression
mod = smf.wls('Y ~ M', weights=final_df['weight'], data=final_df).fit()
rob = mod.get_robustcov_results(cov_type='HC0')
print(mod.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.017
# Model:                            WLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8484
# Date:                Sat, 23 Apr 2022   Prob (F-statistic):              0.362
# Time:                        14:39:02   Log-Likelihood:                -294.74
# No. Observations:                  51   AIC:                             593.5
# Df Residuals:                      49   BIC:                             597.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    118.5515     14.211      8.342      0.000      89.994     147.109
# M            -18.8432     20.458     -0.921      0.362     -59.954      22.268
# ==============================================================================
# Omnibus:                       93.798   Durbin-Watson:                   2.304
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2266.114
# Skew:                           5.134   Prob(JB):                         0.00
# Kurtosis:                      33.999   Cond. No.                         2.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Therefore, by using IP weighting method, the treatment effect is **-18.843**. But this result is NOT significant due to the relative high p-value.

# %% [markdown]
# ### Standardization Method

# %%
mod = smf.ols('Y~ M + A1 + A2 + A3+ A4', data=final_df).fit()
rob = mod.get_robustcov_results(cov_type='HC0')
print(mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.9543
# Date:                Sat, 23 Apr 2022   Prob (F-statistic):              0.456
# Time:                        14:39:03   Log-Likelihood:                -298.61
# No. Observations:                  51   AIC:                             609.2
# Df Residuals:                      45   BIC:                             620.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    296.0431     96.213      3.077      0.004     102.259     489.827
# M             20.5945     37.468      0.550      0.585     -54.869      96.058
# A1           -11.8689      8.643     -1.373      0.176     -29.277       5.539
# A2          9.154e-05      0.001      0.153      0.879      -0.001       0.001
# A3           -17.6199     13.481     -1.307      0.198     -44.772       9.532
# A4             0.0061      0.010      0.597      0.554      -0.014       0.027
# ==============================================================================
# Omnibus:                       92.569   Durbin-Watson:                   2.284
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2138.577
# Skew:                           5.046   Prob(JB):                         0.00
# Kurtosis:                      33.076   Cond. No.                     2.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df1 = final_df.copy()
df1['M'] = 0
df2 = final_df.copy()
df2['M'] = 1
pred1 = mod.predict(df1)
pred2 = mod.predict(df2)
np.mean(pred2 - pred1)
# Out:
# 20.59452839549328

# %% [markdown]
# Since there are strong multicollinearity within the explanatory variables, now we try to remove two confounders with the largest correlation with mask percent which are residential_percent_change_from_baseline and Percent.Unemployed..2018.

# %%
# remove A1 and A3
mod = smf.ols('Y~ M + A2 + A4', data=final_df).fit()
rob = mod.get_robustcov_results(cov_type='HC0')
print(mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                 -0.033
# Method:                 Least Squares   F-statistic:                    0.4685
# Date:                Sat, 23 Apr 2022   Prob (F-statistic):              0.706
# Time:                        14:39:03   Log-Likelihood:                -300.43
# No. Observations:                  51   AIC:                             608.9
# Df Residuals:                      47   BIC:                             616.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    123.1542     16.370      7.523      0.000      90.221     156.087
# M            -18.4344     29.145     -0.633      0.530     -77.066      40.197
# A2            -0.0002      0.001     -0.401      0.690      -0.001       0.001
# A4            -0.0046      0.008     -0.555      0.581      -0.021       0.012
# ==============================================================================
# Omnibus:                       99.591   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2860.582
# Skew:                           5.598   Prob(JB):                         0.00
# Kurtosis:                      37.940   Cond. No.                     6.28e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.28e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# By using standardization method, the threatment effect is **-18.434** which is quite similar to the IP weighting result. And it is also NOT significant.

# %% [markdown]
# ## g-estimation

# %%
g_est_df = final_df.copy()

def H_phi(df, phi):
    df['H_phi'] = df['Y'] - phi*df['M']
    return df

def g_est_solver(phi, df = g_est_df):
    prop = smf.glm('M ~ A2 + A4 + H_phi',family=sm.families.Binomial(), 
                   data=H_phi(df, phi)).fit()
    return prop.params.values[-1]

# %%
scipy.optimize.root_scalar(g_est_solver, bracket = [-100,100], method = 'bisect', maxiter=50)
# Out:
#       converged: True
#            flag: 'converged'
#  function_calls: 49
#      iterations: 47
#            root: -11.250867943572018

# %%
prop = smf.glm('M ~ A2 + A4 + H_phi',family=sm.families.Binomial(),
               data=H_phi(g_est_df, -11.25)).fit()

print(prop.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      M   No. Observations:                   51
# Model:                            GLM   Df Residuals:                       47
# Model Family:                Binomial   Df Model:                            3
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -20.861
# Date:                Sat, 23 Apr 2022   Deviance:                       41.722
# Time:                        14:39:06   Pearson chi2:                     42.3
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.7882      1.042     -2.676      0.007      -4.830      -0.746
# A2             0.0001   6.66e-05      1.864      0.062   -6.36e-06       0.000
# A4             0.0074      0.003      2.536      0.011       0.002       0.013
# H_phi      -1.989e-07      0.006  -3.41e-05      1.000      -0.011       0.011
# ==============================================================================

# %% [markdown]
# By using g-estimation method, the threatment effect is **-11.25** which is still reasonably similar to the result of standardization method and IP-weighting.

# %% [markdown]
# ## Instrument Variable

# %%
final_df['const'] = 1

# Fit the first stage regression and print summary
results_fs = sm.OLS(final_df['M'],
                    final_df[['const', 'Z']],
                    missing='drop').fit()
print(results_fs.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      M   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     2.443
# Date:                Sat, 23 Apr 2022   Prob (F-statistic):              0.124
# Time:                        14:39:08   Log-Likelihood:                -34.061
# No. Observations:                  51   AIC:                             72.12
# Df Residuals:                      49   BIC:                             75.99
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4800      0.096      4.985      0.000       0.287       0.673
# Z             -0.2108      0.135     -1.563      0.124      -0.482       0.060
# ==============================================================================
# Omnibus:                       59.525   Durbin-Watson:                   1.523
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.129
# Skew:                           0.487   Prob(JB):                       0.0283
# Kurtosis:                       1.449   Cond. No.                         2.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
final_df['pred_M'] = results_fs.predict()

results_ss = sm.OLS(final_df['Y'],
                    final_df[['const', 'pred_M','A1','A2','A3','A4']]).fit()
print(results_ss.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9767
# Date:                Sat, 23 Apr 2022   Prob (F-statistic):              0.442
# Time:                        14:44:33   Log-Likelihood:                -298.55
# No. Observations:                  51   AIC:                             609.1
# Df Residuals:                      45   BIC:                             620.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        284.2217     85.988      3.305      0.002     111.033     457.410
# pred_M       -83.2198    130.913     -0.636      0.528    -346.891     180.452
# A1            -7.4533      7.137     -1.044      0.302     -21.829       6.922
# A2             0.0001      0.001      0.192      0.848      -0.001       0.001
# A3           -15.6636     13.196     -1.187      0.241     -42.241      10.914
# A4             0.0047      0.010      0.471      0.640      -0.015       0.025
# ==============================================================================
# Omnibus:                       92.045   Durbin-Watson:                   2.354
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2099.828
# Skew:                           5.003   Prob(JB):                         0.00
# Kurtosis:                      32.800   Cond. No.                     2.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# By Having instrument Variable, the threatment effect is -83.25 which is still within a comparatively reasonable range of results of standardization method ,IP-weighting and g-estimation.
